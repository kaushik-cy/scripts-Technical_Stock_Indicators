# %%
import stonkslab as sl
import stonksplot as sp

# %%
stock = 'SBIN.NS'
start_date = '2015-01-01'
end_date = '2021-02-28'

# %%
data = sl.download_data(stock, start_date, end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_i = sl.all_indicators(data)
data_i.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-02-22  400.600006  401.000000  385.649994  389.500000  389.500000
# 2021-02-23  392.000000  399.700012  389.000000  395.600006  395.600006
# 2021-02-24  397.000000  410.500000  395.200012  406.250000  406.250000
# 2021-02-25  411.000000  414.899994  406.549988  407.250000  407.250000
# 2021-02-26  399.500000  401.000000  387.000000  390.149994  390.149994
#
#               Volume    change       MA_50     MA_200    MA_Diff  ...  \
# Date                                                              ...
# 2021-02-22  52535049 -2.580228  313.650002  226.77275  86.877252  ...
# 2021-02-23  45462768  1.541963  316.113002  227.92350  88.189502  ...
# 2021-02-24  39632090  2.621537  318.754002  229.12025  89.633752  ...
# 2021-02-25  46988836  0.245549  321.486002  230.28600  91.200002  ...
# 2021-02-26  64450414 -4.382931  323.901002  231.39700  92.504002  ...
#
# ...

# %%
sp.DIMS = (15,7.5)

# %% [markdown]
# # Change

# %%
sp.plot_change(data_i, 260)

# %% [markdown]
# # Moving Average

# %%
sp.plot_MA(data_i, 260)

# %% [markdown]
# # MACD

# %%
sp.plot_MACD(data_i, 260)

# %% [markdown]
# # RSI

# %%
sp.plot_RSI(data_i, 260)

# %% [markdown]
# # ADX

# %%
sp.plot_ADX(data_i, 260)

# %% [markdown]
# # CCI

# %%
sp.plot_CCI(data_i, 260)

# %% [markdown]
# # CMF

# %%
sp.plot_CMF(data_i, 260)

# %% [markdown]
# # Stochastic Oscillator

# %%
sp.plot_stochastic_oscillator(data_i, 260)

# %% [markdown]
# # Bollinger Bands

# %%
sp.plot_bollinger_bands(data_i, 260)

# %% [markdown]
# # Ichimoku Cloud

# %%
sp.plot_ichimoku_cloud(data_i, 260)
